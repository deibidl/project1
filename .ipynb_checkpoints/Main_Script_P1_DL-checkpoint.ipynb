# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import statsmodels.formula.api as smf
import seaborn as sns

# %%
# CAS API Keys
api_key = "85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98"

#base_url = "https://api.census.gov/data/2014/acs/acs1"

# %%
# Importing the Data
c = Census(api_key, year=2014)
print(c)
# Out:
# <census.core.Census object at 0x1a18fcafd0>

# %%
census_data = c.acs5.get(("NAME"      , "COUNTY"     , "B06010_001E", "B01002_001E",
                         "B06009_001E", "B06009_002E", "B06009_003E", "B06009_004E", 
                         "B06009_005E", "B06009_006E", "B02001_001E", "B02001_002E",
                         "B02001_003E", "B02001_004E", "B02001_005E", "B02001_006E",
                         "B02001_007E", "B02001_008E", "B01001_026E", "B01001_002E",
                         "B23025_005E", "B05010_001E", "B01003_001E"),{'for': 'county:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

census_pd.head()
# Out:
#    B01001_002E  B01001_026E  B01002_001E  B01003_001E  B02001_001E  \
# 0    4913688.0    5060515.0         35.3    9974203.0    9974203.0
# 1      73450.0      79002.0         33.3     152452.0     152452.0
# 2     125838.0     130964.0         45.1     256802.0     256802.0
# 3       9050.0       8896.0         50.2      17946.0      17946.0
# 4      43979.0      43633.0         42.0      87612.0      87612.0
#
#    B02001_002E  B02001_003E  B02001_004E  B02001_005E  B02001_006E  ...  \
# 0    5329333.0     832253.0      54409.0    1394349.0      26074.0  ...
# 1     125830.0       5382.0       2287.0       3335.0        254.0  ...
# 2     203975.0       6913.0        674.0      14565.0        593.0  ...
# 3      15850.0        155.0        598.0        232.0         74.0  ...
# 4      72141.0        705.0       4169.0       1570.0        186.0  ...
#
#    B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  \
# 0    1347268.0    1728972.0    1281851.0     679412.0    8049317.0
# 1      22190.0      30369.0       8858.0       3804.0     116777.0
# 2      23040.0      48100.0      58107.0      45233.0     212605.0
# 3       3826.0       5251.0       2006.0       1050.0      15468.0
# 4      16137.0      22575.0       8930.0       4842.0      71774.0
#
#    B23025_005E  COUNTY                            NAME  county  state
# 0     564669.0     037  Los Angeles County, California     037     06
# 1       5530.0     039       Madera County, California     039     06
# 2       9756.0     041        Marin County, California     041     06
# 3       1132.0     043     Mariposa County, California     043     06
# 4       5193.0     045    Mendocino County, California     045     06
#
# [5 rows x 25 columns]

# %%
# Column Reordering
census_pd = census_pd.rename(columns={"NAME"        : "county_name"       ,
                                      "COUNTY"      : "county"            , 
                                      "B06010_001E" : "gross_income"      , 
                                      "B01002_001E" : "median_age"        ,
                                      "B06009_001E" : "years_of_education", 
                                      "B06009_002E" : "less_than_hs"      , 
                                      "B06009_003E" : "high_school"       , 
                                      "B06009_004E" : "some_college"      , 
                                      "B06009_005E" : "college"           , 
                                      "B06009_006E" : "grad_school"       , 
                                      "B02001_001E" : "total_race"        , 
                                      "B02001_002E" : "white"             ,
                                      "B02001_003E" : "black"             , 
                                      "B02001_004E" : "native_american"   , 
                                      "B02001_005E" : "asian"             , 
                                      "B02001_006E" : "pacific_islander"  ,
                                      "B02001_007E" : "other"             , 
                                      "B02001_008E" : "multi_racial"      , 
                                      "B01001_026E" : "female"            , 
                                      "B01001_002E" : "male"              ,
                                      "B23025_005E" : "unemployment_rate" ,
                                      "B05010_001E" : "poverty_rate"      , 
                                      "B01003_001E" : "population_size"   })

census_pd.head()
# Out:
#         male     female  median_age  population_size  total_race      white  \
# 0  4913688.0  5060515.0        35.3        9974203.0   9974203.0  5329333.0
# 1    73450.0    79002.0        33.3         152452.0    152452.0   125830.0
# 2   125838.0   130964.0        45.1         256802.0    256802.0   203975.0
# 3     9050.0     8896.0        50.2          17946.0     17946.0    15850.0
# 4    43979.0    43633.0        42.0          87612.0     87612.0    72141.0
#
#       black  native_american      asian  pacific_islander  ...  high_school  \
# 0  832253.0          54409.0  1394349.0           26074.0  ...    1347268.0
# 1    5382.0           2287.0     3335.0             254.0  ...      22190.0
# 2    6913.0            674.0    14565.0             593.0  ...      23040.0
# 3     155.0            598.0      232.0              74.0  ...       3826.0
# 4     705.0           4169.0     1570.0             186.0  ...      16137.0
#
#    some_college    college  grad_school  gross_income  unemployment_rate  \
# 0     1728972.0  1281851.0     679412.0     8049317.0           564669.0
# 1       30369.0     8858.0       3804.0      116777.0             5530.0
# 2       48100.0    58107.0      45233.0      212605.0             9756.0
# 3        5251.0     2006.0       1050.0       15468.0             1132.0
# 4       22575.0     8930.0       4842.0       71774.0             5193.0
#
#    county                     county_name  county  state
# 0     037  Los Angeles County, California     037     06
# 1     039       Madera County, California     039     06
# 2     041        Marin County, California     041     06
# 3     043     Mariposa County, California     043     06
# 4     045    Mendocino County, California     045     06
#
# [5 rows x 25 columns]

# %%
# Values per capita

census_pd["gross_income_pc"]       = census_pd["gross_income"] / census_pd["population_size"] 
census_pd["years_of_education_pc"] = census_pd["years_of_education"] / census_pd["population_size"] 
census_pd["less_than_hs"]          = census_pd["less_than_hs"] / census_pd["population_size"] 
census_pd["high_school_pc"]        = census_pd["high_school"] / census_pd["population_size"] 
census_pd["some_college_pc"]       = census_pd["some_college"] / census_pd["population_size"] 
census_pd["college_pc"]            = census_pd["college"] / census_pd["population_size"] 
census_pd["grad_school_pc"]        = census_pd["grad_school"] / census_pd["population_size"] 
census_pd["total_race_pc"]         = census_pd["total_race"] / census_pd["population_size"] 
census_pd["white_pc"]              = census_pd["white"] / census_pd["population_size"]
census_pd["black_pc"]              = census_pd["black"] / census_pd["population_size"]
census_pd["native_american_pc"]    = census_pd["native_american"] / census_pd["population_size"]
census_pd["asian_pc"]              = census_pd["asian"] / census_pd["population_size"]
census_pd["pacific_islander_pc"]   = census_pd["pacific_islander"]/ census_pd["population_size"]
census_pd["other_pc"]              = census_pd["other"] / census_pd["population_size"]
census_pd["multi_racial_pc"]       = census_pd["multi_racial"] / census_pd["population_size"]
census_pd["female_pc"]             = census_pd["female"] / census_pd["population_size"]
census_pd["male_pc"]               = census_pd["male"] / census_pd["population_size"]
census_pd["unemployment_rate_pc"]  = census_pd["unemployment_rate"] / census_pd["population_size"]
census_pd["poverty_rate_pc"]       = census_pd["poverty_rate"] / census_pd["population_size"]

census_pd.head()
# Out:
#         male     female  median_age  population_size  total_race      white  \
# 0  4913688.0  5060515.0        35.3        9974203.0   9974203.0  5329333.0
# 1    73450.0    79002.0        33.3         152452.0    152452.0   125830.0
# 2   125838.0   130964.0        45.1         256802.0    256802.0   203975.0
# 3     9050.0     8896.0        50.2          17946.0     17946.0    15850.0
# 4    43979.0    43633.0        42.0          87612.0     87612.0    72141.0
#
#       black  native_american      asian  pacific_islander  ...  black_pc  \
# 0  832253.0          54409.0  1394349.0           26074.0  ...  0.083441
# 1    5382.0           2287.0     3335.0             254.0  ...  0.035303
# 2    6913.0            674.0    14565.0             593.0  ...  0.026920
# 3     155.0            598.0      232.0              74.0  ...  0.008637
# 4     705.0           4169.0     1570.0             186.0  ...  0.008047
#
#    native_american_pc  asian_pc  pacific_islander_pc  other_pc  \
# 0            0.005455  0.139796             0.002614  0.195498
# 1            0.015001  0.021876             0.001666  0.067261
# 2            0.002625  0.056717             0.002309  0.076573
# 3            0.033322  0.012928             0.004123  0.022233
# 4            0.047585  0.017920             0.002123  0.063188
#
#    multi_racial_pc  female_pc   male_pc  unemployment_rate_pc  poverty_rate_pc
# 0         0.038885   0.507360  0.492640              0.056613         0.224347
# 1         0.033519   0.518209  0.481791              0.036274         0.267205
# 2         0.040568   0.509980  0.490020              0.037990         0.199909
# 3         0.035551   0.495709  0.504291              0.063078         0.159200
# 4         0.037723   0.498025  0.501975              0.059273         0.199801
#
# [5 rows x 43 columns]

# %%
#CoolClimate Data
climate_data_to_load = "climate_data_county_ajc.csv"
climate_pd = pd.read_csv(climate_data_to_load)
climate_pd.head()
# Out:
# Index(['Population', 'State', 'County', 'electricity (kWh)',
#        'Nat. Gas (cu.ft.)', 'FUELOIL (gallons)', 'Vehicle miles traveled',
#        ' Transport (tCO2e/yr) ', ' Housing (tCO2e/yr) ', ' Food (tCO2e/yr) ',
#        ' Goods (tCO2e/yr) ', ' Services (tCO2e/yr) ',
#        ' Total Household Carbon Footprint (tCO2e/yr) ', ' Households ',
#        ' Total County Carbon Footprint (tCO2e/yr) '],
#       dtype='object')

# %%
# Data with County and State
us_states_to_load = "us_states.csv"

us_states_df = pd.read_csv(us_states_to_load, 
                           header = None)

us_states_df.columns = ["Upper Full Name", 
                        "Proper Full Name", 
                        "State"]
us_states_df.head()
# Out:
#   Upper Full Name Proper Full Name State
# 0         ALABAMA          Alabama    AL
# 1          ALASKA           Alaska    AK
# 2         ARIZONA          Arizona    AZ
# 3        ARKANSAS         Arkansas    AR
# 4      CALIFORNIA       California    CA

# %%
# Merge both dataframes
states_complete = pd.merge(us_states_df, 
                           climate_pd, 
                           how = "left", 
                           on = ["State"]) 

states_complete
# Out:
#      Upper Full Name Proper Full Name State  Population        County  \
# 0            ALABAMA          Alabama    AL       14387       SUMTER
# 1            ALABAMA          Alabama    AL       13563       WILCOX
# 2            ALABAMA          Alabama    AL       22987        MACON
# 3            ALABAMA          Alabama    AL        9809       GREENE
# 4            ALABAMA          Alabama    AL       12701      BULLOCK
# 5            ALABAMA          Alabama    AL        9830        PERRY
# 6            ALABAMA          Alabama    AL       30485         PIKE
# 7            ALABAMA          Alabama    AL       27630      BARBOUR
# 8            ALABAMA          Alabama    AL       48892      RUSSELL
# 9            ALABAMA          Alabama    AL       13892      CONECUH
# 10           ALABAMA          Alabama    AL       48283       DALLAS
# 11           ALABAMA          Alabama    AL       21281       BUTLER
# 12           ALABAMA          Alabama    AL       12217      LOWNDES
# 13           ALABAMA          Alabama    AL      113557          LEE
# 14           ALABAMA          Alabama    AL       15752      CHOCTAW
# 15           ALABAMA          Alabama    AL       21818      MARENGO
# 16           ALABAMA          Alabama    AL       20311     CHEROKEE
# 17           ALABAMA          Alabama    AL       13694     CRENSHAW
# 18           ALABAMA          Alabama    AL       37223    COVINGTON
# 19           ALABAMA          Alabama    AL       17910         HALE
# 20           ALABAMA          Alabama    AL       86700      HOUSTON
# 21           ALABAMA          Alabama    AL       22817       MONROE
# 22           ALABAMA          Alabama    AL       37244   TALLAPOOSA
# 23           ALABAMA          Alabama    AL       26722       GENEVA
# 24           ALABAMA          Alabama    AL       38461     ESCAMBIA
# 25           ALABAMA          Alabama    AL       36605     CHAMBERS
# 26           ALABAMA          Alabama    AL       21161      PICKENS
# 27           ALABAMA          Alabama    AL       27241      WINSTON
# 28           ALABAMA          Alabama    AL      156029   TUSCALOOSA
# 29           ALABAMA          Alabama    AL       16600        HENRY
# ...              ...              ...   ...         ...           ...
# 3093       WISCONSIN        Wisconsin    WI       20605     KEWAUNEE
# 3094       WISCONSIN        Wisconsin    WI       23664      CALUMET
# 3095       WISCONSIN        Wisconsin    WI       42490       PIERCE
# 3096       WISCONSIN        Wisconsin    WI      118096   WASHINGTON
# 3097       WISCONSIN        Wisconsin    WI      364266     WAUKESHA
# 3098       WISCONSIN        Wisconsin    WI       56489  SAINT CROIX
# 3099       WISCONSIN        Wisconsin    WI       82662      OZAUKEE
# 3100         WYOMING          Wyoming    WY        4882  HOT SPRINGS
# 3101         WYOMING          Wyoming    WY        5893     SUBLETTE
# 3102         WYOMING          Wyoming    WY       31989       ALBANY
# 3103         WYOMING          Wyoming    WY       17930        TETON
# 3104         WYOMING          Wyoming    WY       15567       CARBON
# 3105         WYOMING          Wyoming    WY       25699         PARK
# 3106         WYOMING          Wyoming    WY        8318     WASHAKIE
# 3107         WYOMING          Wyoming    WY       35804      FREMONT
# 3108         WYOMING          Wyoming    WY       14685      LINCOLN
# 3109         WYOMING          Wyoming    WY       26702     SHERIDAN
# 3110         WYOMING          Wyoming    WY       66461      NATRONA
# 3111         WYOMING          Wyoming    WY       12089     CONVERSE
# 3112         WYOMING          Wyoming    WY       81630      LARAMIE
# 3113         WYOMING          Wyoming    WY        9006       PLATTE
# 3114         WYOMING          Wyoming    WY       12486       GOSHEN
# 3115         WYOMING          Wyoming    WY        2370     NIOBRARA
# 3116         WYOMING          Wyoming    WY        7051      JOHNSON
# 3117         WYOMING          Wyoming    WY       11415     BIG HORN
# 3118         WYOMING          Wyoming    WY        6742       WESTON
# 3119         WYOMING          Wyoming    WY       37600   SWEETWATER
# 3120         WYOMING          Wyoming    WY        5945        CROOK
# 3121         WYOMING          Wyoming    WY       19742        UINTA
# 3122         WYOMING          Wyoming    WY       33496     CAMPBELL
#
#      electricity (kWh) Nat. Gas (cu.ft.) FUELOIL (gallons)  \
# 0              12,667            28,415                 6
# 1              12,846            26,873                10
# 2              12,983            34,664                 1
# 3              13,157            29,872                 4
# 4              12,493            28,330                 1
# 5              13,880            32,364                 3
# 6              11,983            27,026                 3
# 7              12,508            27,275                 1
# 8              12,328            28,993                 2
# 9              13,814            28,256                 1
# 10             13,967            34,896                 1
# 11             13,423            28,556               -
# 12             13,513            27,473                 2
# 13             11,882            28,457                 1
# 14             13,004            26,413                 1
# 15             13,389            30,076                 5
# 16             12,084            27,723                 4
# 17             13,202            27,254                 2
# 18             13,714            28,382                 1
# 19             13,762            29,705                 3
# 20             12,740            26,112                 4
# 21             13,634            27,699                 1
# 22             12,925            29,587                 2
# 23             13,501            26,348                 7
# 24             13,302            27,966                 6
# 25             13,519            32,269                 3
# 26             13,600            29,590                11
# 27             12,774            30,125                 4
# 28             13,100            31,178                 2
# 29             13,699            26,358                 7
# ...                ...               ...               ...
# 3093           10,297            47,825               127
# 3094           11,005            55,882               110
# 3095           10,499            48,530                53
# 3096           11,215            60,188                50
# 3097           11,719            68,993                42
# 3098           11,285            53,298                55
# 3099           11,886            69,730                40
# 3100            8,748            55,719                 9
# 3101            9,100            38,349                15
# 3102            7,863            52,751                 0
# 3103            7,407            24,782                15
# 3104            9,193            55,615                 1
# 3105           10,081            59,120                 3
# 3106           10,255            62,921                 1
# 3107            9,131            50,317                 2
# 3108            9,613            37,872                 8
# 3109            9,083            51,039                 1
# 3110           10,005            63,048                 0
# 3111           10,285            54,756               -
# 3112           10,338            65,017                 1
# 3113            9,557            51,954                 2
# 3114            9,901            58,261                 5
# 3115           10,308            55,589                14
# 3116            9,978            55,785                 1
# 3117           11,117            62,857                 3
# 3118            9,357            47,476                 3
# 3119           10,193            68,589                 0
# 3120            9,129            30,660                13
# 3121           10,591            61,980                 1
# 3122           10,247            49,850                 2
#
#      Vehicle miles traveled   Transport (tCO2e/yr)   Housing (tCO2e/yr)   \
# 0                   18,175                     11.9                13.9
# 1                   18,756                     12.2                14.1
# 2                   18,269                     12.1                14.6
# 3                   18,821                     12.4                14.4
# 4                   19,187                     12.6                13.8
# 5                   18,226                     11.9                15.1
# 6                   21,059                     14.0                13.3
# 7                   20,836                     13.8                13.8
# 8                   20,674                     13.8                13.7
# 9                   21,171                     13.9                14.8
# 10                  19,349                     12.8                15.3
# 11                  21,187                     14.0                14.5
# 12                  21,147                     13.9                14.5
# 13                  22,895                     15.3                13.3
# 14                  23,362                     15.3                14.1
# 15                  21,395                     14.2                14.7
# 16                  22,822                     15.3                13.7
# 17                  23,777                     15.7                14.2
# 18                  22,901                     15.2                14.7
# 19                  21,518                     14.2                14.9
# 20                  21,909                     14.8                13.9
# 21                  21,896                     14.6                14.6
# 22                  22,678                     15.2                14.2
# 23                  24,018                     15.8                14.5
# 24                  23,159                     15.4                14.5
# 25                  22,292                     14.9                14.9
# 26                  23,144                     15.3                14.8
# 27                  24,682                     16.3                14.4
# 28                  22,638                     15.3                14.4
# 29                  23,583                     15.7                14.6
# ...                     ...                     ...                  ...
# 3093                29,639                     19.9                16.7
# 3094                29,392                     20.0                17.7
# 3095                32,362                     21.9                16.3
# 3096                29,998                     20.7                16.9
# 3097                29,258                     20.5                17.9
# 3098                32,645                     22.3                17.4
# 3099                29,816                     21.0                18.2
# 3100                23,740                     15.8                10.7
# 3101                24,755                     16.8                 9.8
# 3102                22,066                     14.8                14.1
# 3103                23,348                     16.6                 7.9
# 3104                23,557                     16.0                12.7
# 3105                25,726                     17.3                11.6
# 3106                25,880                     17.3                12.3
# 3107                24,788                     16.5                13.7
# 3108                27,534                     18.5                10.1
# 3109                23,620                     16.0                15.3
# 3110                24,862                     16.8                14.0
# 3111                28,298                     19.0                11.3
# 3112                25,017                     17.0                13.4
# 3113                25,269                     16.9                16.0
# 3114                25,036                     16.7                16.9
# 3115                25,807                     17.1                17.3
# 3116                25,645                     17.1                16.7
# 3117                26,725                     17.7                16.0
# 3118                28,565                     18.9                15.5
# 3119                28,920                     19.6                12.3
# 3120                29,845                     19.8                14.3
# 3121                28,625                     19.3                13.9
# 3122                32,912                     22.2                16.6
#
#        Food (tCO2e/yr)    Goods (tCO2e/yr)    Services (tCO2e/yr)   \
# 0                   7.7                 3.7                    3.8
# 1                   8.2                 3.7                    3.7
# 2                   7.3                 3.9                    4.0
# 3                   7.5                 3.7                    3.9
# 4                   7.7                 3.9                    4.0
# 5                   8.0                 3.7                    3.8
# 6                   7.2                 4.1                    4.3
# 7                   7.6                 4.1                    4.3
# 8                   7.5                 4.3                    4.6
# 9                   7.3                 3.9                    4.1
# 10                  7.7                 4.0                    4.2
# 11                  7.5                 4.0                    4.2
# 12                  8.2                 4.0                    4.1
# 13                  7.3                 4.4                    4.8
# 14                  7.4                 4.0                    4.3
# 15                  7.6                 4.2                    4.5
# 16                  7.2                 4.4                    4.8
# 17                  7.2                 4.1                    4.3
# 18                  7.1                 4.1                    4.4
# 19                  7.9                 4.2                    4.4
# 20                  7.3                 4.6                    5.1
# 21                  7.7                 4.3                    4.6
# 22                  7.3                 4.5                    4.9
# 23                  7.3                 4.1                    4.4
# 24                  7.4                 4.3                    4.6
# 25                  7.5                 4.4                    4.7
# 26                  7.7                 4.2                    4.5
# 27                  7.3                 4.2                    4.5
# 28                  7.2                 4.7                    5.1
# 29                  7.5                 4.4                    4.8
# ...                 ...                 ...                    ...
# 3093                7.9                 5.3                    5.9
# 3094                7.8                 5.6                    6.3
# 3095                7.9                 5.7                    6.4
# 3096                8.0                 6.2                    7.1
# 3097                7.9                 6.6                    7.6
# 3098                8.0                 6.2                    7.0
# 5                                      181,153
# 6                                      618,425
# 7                                      511,117
# 8                                    1,171,923
# 9                                      307,713
# 10                                     937,449
# 11                                     444,238
# 12                                     237,817
# 13                                   3,065,726
# 14                                     352,425
# 15                                     441,497
# 16                                     563,662
# 17                                     309,934
# 18                                     835,817
# 19                                     368,301
# 20                                   1,776,292
# 21                                     487,965
# 22                                     862,017
# 23                                     577,203
# 24                                     764,456
# 25                                     760,309
# 26                                     449,585
# 27                                     620,924
# 28                                   3,176,042
# 29                                     382,031
# ...                                         ...
# 3093                                   477,972
# 3094                                   546,848
# 3095                                   913,916
# 3096                                 2,709,614
# 3097                                 8,590,987
# 3098                                 1,321,736
# 3099                                 1,994,255
# 3100                                   107,156
# 3101                                   155,973
# 3102                                   667,977
# 3103                                   436,914
# 3104                                   379,767
# 3105                                   543,811
# 3106                                   171,758
# 3107                                   738,509
# 3108                                   321,755
# 3109                                   607,786
# 3110                                 1,436,040
# 3111                                   275,871
# 3112                                 1,625,902
# 3113                                   239,228
# 3114                                   292,947
# 3115                                    66,073
# 3116                                   179,174
# 3117                                   255,967
# 3118                                   167,385
# 3119                                   817,863
# 3120                                   153,335
# 3121                                   426,372
# 3122                                   780,405
#
# [3123 rows x 17 columns]

# %%
# Getting variables in the correct format
states_complete["County"] = states_complete["County"].str.title()
states_complete.head()
# Out:
#   Upper Full Name Proper Full Name State  Population    County  \
# 0         ALABAMA          Alabama    AL       14387   Sumter
# 1         ALABAMA          Alabama    AL       13563   Wilcox
# 2         ALABAMA          Alabama    AL       22987    Macon
# 3         ALABAMA          Alabama    AL        9809   Greene
# 4         ALABAMA          Alabama    AL       12701  Bullock
#
#   electricity (kWh) Nat. Gas (cu.ft.) FUELOIL (gallons)  \
# 0           12,667            28,415                 6
# 1           12,846            26,873                10
# 2           12,983            34,664                 1
# 3           13,157            29,872                 4
# 4           12,493            28,330                 1
#
#   Vehicle miles traveled   Transport (tCO2e/yr)   Housing (tCO2e/yr)   \
# 0                18,175                     11.9                13.9
# 1                18,756                     12.2                14.1
# 2                18,269                     12.1                14.6
# 3                18,821                     12.4                14.4
# 4                19,187                     12.6                13.8
#
#     Food (tCO2e/yr)    Goods (tCO2e/yr)    Services (tCO2e/yr)   \
# 0                7.7                 3.7                    3.8
# 1                8.2                 3.7                    3.7
# 2                7.3                 3.9                    4.0
# 3                7.5                 3.7                    3.9
# 4                7.7                 3.9                    4.0
#
#     Total Household Carbon Footprint (tCO2e/yr)    Households   \
# 0                                           41.0        6654.0
# 1                                           41.8        6293.0
# 2                                           41.9       10104.0
# 3                                           41.9        5029.0
# 4                                           41.9        5166.0
#
#    Total County Carbon Footprint (tCO2e/yr)
# 0                                   272,685
# 1                                   262,872
# 2                                   422,969
# 3                                   210,619
# 4                                   216,678

# %%
# Creating the keys to merge the data sets
states_complete["county_name"] = states_complete["County"] + "County, " + states_complete["Proper Full Name"]
states_complete.head()
# Out:
#   Upper Full Name Proper Full Name State  Population    County  \
# 0         ALABAMA          Alabama    AL       14387   Sumter
# 1         ALABAMA          Alabama    AL       13563   Wilcox
# 2         ALABAMA          Alabama    AL       22987    Macon
# 3         ALABAMA          Alabama    AL        9809   Greene
# 4         ALABAMA          Alabama    AL       12701  Bullock
#
#   electricity (kWh) Nat. Gas (cu.ft.) FUELOIL (gallons)  \
# 0           12,667            28,415                 6
# 1           12,846            26,873                10
# 2           12,983            34,664                 1
# 3           13,157            29,872                 4
# 4           12,493            28,330                 1
#
#   Vehicle miles traveled   Transport (tCO2e/yr)   Housing (tCO2e/yr)   \
# 0                18,175                     11.9                13.9
# 1                18,756                     12.2                14.1
# 2                18,269                     12.1                14.6
# 3                18,821                     12.4                14.4
# 4                19,187                     12.6                13.8
#
#     Food (tCO2e/yr)    Goods (tCO2e/yr)    Services (tCO2e/yr)   \
# 0                7.7                 3.7                    3.8
# 1                8.2                 3.7                    3.7
# 2                7.3                 3.9                    4.0
# 3                7.5                 3.7                    3.9
# 4                7.7                 3.9                    4.0
#
#     Total Household Carbon Footprint (tCO2e/yr)    Households   \
# 0                                           41.0        6654.0
# 1                                           41.8        6293.0
# 2                                           41.9       10104.0
# 3                                           41.9        5029.0
# 4                                           41.9        5166.0
#
#    Total County Carbon Footprint (tCO2e/yr)               county_name
# 0                                   272,685    Sumter County, Alabama
# 1                                   262,872    Wilcox County, Alabama
# 2                                   422,969     Macon County, Alabama
# 3                                   210,619    Greene County, Alabama
# 4                                   216,678   Bullock County, Alabama

# %%
# Renaming some variables
states_complete = states_complete.rename(columns={"Upper Full Name"                              : "upper_state"       ,
                                                  "Proper Full Name"                             : "title_state"       ,
                                                  "State"                                        : "state_abbrev"      ,
                                                  "Population"                                   : "population"        ,
                                                  "County"                                       : "county"            ,
                                                  "electricity (kWh)"                            : "electricity"       ,
                                                  "Nat. Gas (cu.ft.)"                            : "natural_gas"       ,
                                                  "FUELOIL (gallons)"                            : "fuel_oil"          ,
                                                  "Vehicle miles traveled"                       : "vehicle_miles"     ,
                                                  " Transport (tCO2e/yr) "                       : "transport_fp"      ,
                                                  " Housing (tCO2e/yr) "                         : "housing_fp"        ,
                                                  " Food (tCO2e/yr) "                            : "food_fp"           ,
                                                  " Goods (tCO2e/yr) "                           : "goods_fp"          ,
                                                  " Services (tCO2e/yr) "                        : "services_fp"       ,
                                                  " Total Household Carbon Footprint (tCO2e/yr) ": "household_total_fp",
                                                  " Households "                                 : "household_count"   ,
                                                  " Total County Carbon Footprint (tCO2e/yr) "   : "county_total_fp"}  )
states_complete.head()
# Out:
#   upper_state title_state state_abbrev  population    county electricity  \
# 0     ALABAMA     Alabama           AL       14387   Sumter      12,667
# 1     ALABAMA     Alabama           AL       13563   Wilcox      12,846
# 2     ALABAMA     Alabama           AL       22987    Macon      12,983
# 3     ALABAMA     Alabama           AL        9809   Greene      13,157
# 4     ALABAMA     Alabama           AL       12701  Bullock      12,493
#
#   natural_gas fuel_oil vehicle_miles  transport_fp housing_fp  food_fp  \
# 0     28,415        6        18,175           11.9      13.9       7.7
# 1     26,873       10        18,756           12.2      14.1       8.2
# 2     34,664        1        18,269           12.1      14.6       7.3
# 3     29,872        4        18,821           12.4      14.4       7.5
# 4     28,330        1        19,187           12.6      13.8       7.7
#
#    goods_fp  services_fp  household_total_fp  household_count county_total_fp  \
# 0       3.7          3.8                41.0           6654.0        272,685
# 1       3.7          3.7                41.8           6293.0        262,872
# 2       3.9          4.0                41.9          10104.0        422,969
# 3       3.7          3.9                41.9           5029.0        210,619
# 4       3.9          4.0                41.9           5166.0        216,678
#
#                county_name
# 0   Sumter County, Alabama
# 1   Wilcox County, Alabama
# 2    Macon County, Alabama
# 3   Greene County, Alabama
# 4  Bullock County, Alabama

# %%
climate_census = pd.merge(census_pd,
                          states_complete,
                          how = "inner",
                          on = "county_name")
climate_census.columns
# Out:
# Index(['male', 'female', 'median_age', 'population_size', 'total_race',
#        'white', 'black', 'native_american', 'asian', 'pacific_islander',
#        'other', 'multi_racial', 'poverty_rate', 'years_of_education',
#        'less_than_hs', 'high_school', 'some_college', 'college', 'grad_school',
#        'gross_income', 'unemployment_rate', 'county_x', 'county_name',
#        'county_x', 'state', 'gross_income_pc', 'years_of_education_pc',
#        'high_school_pc', 'some_college_pc', 'college_pc', 'grad_school_pc',
#        'total_race_pc', 'white_pc', 'black_pc', 'native_american_pc',
#        'asian_pc', 'pacific_islander_pc', 'other_pc', 'multi_racial_pc',
#        'female_pc', 'male_pc', 'unemployment_rate_pc', 'poverty_rate_pc',
#        'upper_state', 'title_state', 'state_abbrev', 'population', 'county_y',
#        'electricity', 'natural_gas', 'fuel_oil', 'vehicle_miles',
#        'transport_fp', 'housing_fp', 'food_fp', 'goods_fp', 'services_fp',
#        'household_total_fp', 'household_count', 'county_total_fp'],
#       dtype='object')

# %%
climate_census["pop_household"] = climate_census["population_size"] / climate_census["household_count"]  
climate_census
# Out:
#            male     female  median_age  population_size  total_race  \
# 0     4913688.0  5060515.0        35.3        9974203.0   9974203.0
# 1       73450.0    79002.0        33.3         152452.0    152452.0
# 2      125838.0   130964.0        45.1         256802.0    256802.0
# 3        9050.0     8896.0        50.2          17946.0     17946.0
# 4       43979.0    43633.0        42.0          87612.0     87612.0
# 5      131899.0   129710.0        30.2         261609.0    261609.0
# 6        4727.0     4608.0        47.1           9335.0      9335.0
# 7        7520.0     6673.0        37.2          14193.0     14193.0
# 8      218060.0   206867.0        33.3         424927.0    424927.0
# 9       69301.0    69952.0        40.3         139253.0    139253.0
# 10      48812.0    49794.0        48.8          98606.0     98606.0
# 11    1525071.0  1561260.0        36.7        3086331.0   3086331.0
# 12     176490.0   185028.0        40.7         361518.0    361518.0
# 13       9754.0     9532.0        50.6          19286.0     19286.0
# 14    1127924.0  1138975.0        34.2        2266899.0   2266899.0
# 15     709679.0   740598.0        35.3        1450277.0   1450277.0
# 16      28428.0    28460.0        34.8          56888.0     56888.0
# 17    1033761.0  1044825.0        32.2        2078586.0   2078586.0
# 18    1598266.0  1584877.0        34.9        3183143.0   3183143.0
# 2909                51.5           4009.0         206,613        1.735345
# 2910                48.3         934772.0      45,134,494        2.619829
# 2911                45.1           5343.0         240,855        2.544076
# 2912                50.5           6841.0         345,563        2.825756
# 2913                46.2           2410.0         111,324        2.173859
# 2914                57.3         186153.0      10,661,106        3.806691
# 2915                44.1           1707.0          75,199        1.370240
# 2916                44.6           3965.0         176,665        2.657503
# 2917                44.6           2405.0         107,268        1.511850
# 2918                44.5           5861.0         260,560        1.986692
# 2919                43.6          10009.0         436,378        1.838645
# 2920                44.5          50246.0       2,238,009        2.884449
#
# [2921 rows x 61 columns]

# %%
variables_to_clean = ['electricity'  , 'natural_gas', 'fuel_oil'       , 
                      'vehicle_miles', 'housing_fp' , 'county_total_fp']

for variable in variables_to_clean:
    climate_census[variable] = climate_census[variable].str.replace(' ', '')
    climate_census[variable] = climate_census[variable].str.replace('-', '')
    climate_census[variable] = climate_census[variable].str.replace(',', '')

# %%
# Correlation Matrix

independent_variables = ['gross_income_pc', 'high_school_pc'     ,  'some_college_pc'     , 'college_pc'        , 
                         'grad_school_pc' , 'white_pc'           ,  'black_pc'            , 'native_american_pc', 
                         'asian_pc'       , 'pacific_islander_pc',  'other_pc'            , 'multi_racial_pc'   ,
                         'female_pc'      , 'male_pc'            ,  'unemployment_rate_pc', 'poverty_rate_pc'   , 
                         'pop_household']

data_for_correlation = climate_census[independent_variables]
sns.heatmap(data_for_correlation.corr())

# %%
#Regression with robustcov
# Regressions on transportation
lm_transport = smf.ols(formula = 'transport_fp ~ high_school_pc + some_college_pc + college_pc + grad_school_pc + black_pc + native_american_pc + asian_pc + pacific_islander_pc + other_pc + multi_racial_pc + female_pc + unemployment_rate_pc + poverty_rate_pc + pop_household', 
                       data = climate_census).fit().get_robustcov_results()
#print(lm_transport.params) 
lm_transport_summary = lm_transport.summary()
lm_transport_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           transport_fp   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     144.6
# Date:                Sat, 24 Aug 2019   Prob (F-statistic):          1.72e-320
# Time:                        12:48:07   Log-Likelihood:                -5729.2
# No. Observations:                2920   AIC:                         1.149e+04
# Df Residuals:                    2905   BIC:                         1.158e+04
# Df Model:                          14
# Covariance Type:                  HC1
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                4.8449      1.094      4.428      0.000       2.700       6.990
# high_school_pc          11.6870      1.247      9.375      0.000       9.243      14.131
# some_college_pc         12.5080      1.194     10.474      0.000      10.167      14.849
# college_pc              15.9154      1.993      7.987      0.000      12.008      19.823
# grad_school_pc           5.4794      3.118      1.757      0.079      -0.634      11.593
# black_pc                -3.1966      0.268    -11.925      0.000      -3.722      -2.671
# native_american_pc      -6.6224      0.534    -12.412      0.000      -7.668      -5.576
# asian_pc                -0.0274      2.785     -0.010      0.992      -5.488       5.433
# pacific_islander_pc    -35.2418     10.270     -3.432      0.001     -55.378     -15.105
# other_pc                -7.3430      1.391     -5.277      0.000     -10.071      -4.615
# multi_racial_pc         -0.0735      1.989     -0.037      0.971      -3.974       3.827
# female_pc               -7.0380      1.929     -3.649      0.000     -10.819      -3.256
# unemployment_rate_pc   -12.6472      2.850     -4.438      0.000     -18.235      -7.060
# poverty_rate_pc         34.1354      1.644     20.761      0.000      30.911      37.359
# pop_household            0.7648      0.104      7.331      0.000       0.560       0.969
# ==============================================================================
# Omnibus:                      109.603   Durbin-Watson:                   1.526
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.500
# Skew:                           0.162   Prob(JB):                     3.35e-61
# Kurtosis:                       4.478   Cond. No.                         839.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
#Regression
# Regressions on  housing
lm_housing = smf.ols(formula = 'housing_fp ~ gross_income_pc + high_school_pc + some_college_pc + college_pc + grad_school_pc + white_pc + black_pc + native_american_pc + asian_pc + pacific_islander_pc + other_pc + multi_racial_pc + female_pc + male_pc + unemployment_rate_pc + poverty_rate_pc', data = climate_census).fit().get_robustcov_results()
#print(lm_housing.params) 
lm_housing_summary = lm_housing.summary()

#Regression
# Regressions on goods 
lm_goods = smf.ols(formula = 'goods_fp ~ gross_income_pc + high_school_pc + some_college_pc + college_pc + grad_school_pc + white_pc + black_pc + native_american_pc + asian_pc + pacific_islander_pc + other_pc + multi_racial_pc + female_pc + male_pc + unemployment_rate_pc + poverty_rate_pc', data = climate_census).fit().get_robustcov_results()
#print(lm_goods.params) 
lm_goods_summary = lm_goods.summary()

#Regression
# Regressions on services 
lm_services = smf.ols(formula = 'services_fp ~ gross_income_pc + high_school_pc + some_college_pc + college_pc + grad_school_pc + white_pc + black_pc + native_american_pc + asian_pc + pacific_islander_pc + other_pc + multi_racial_pc + female_pc + male_pc + unemployment_rate_pc + poverty_rate_pc', data = climate_census).fit().get_robustcov_results()
#print(lm_services.params) 
lm_services_summary = lm_services.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1532: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 17, but rank is 16
#   'rank is %d' % (J, J_), ValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-c5a097974055> in <module>
#       8 #Regression
#       9 # Regressions on  housing
# ---> 10 lm_housing = smf.ols(formula = 'housing_fp ~ gross_income_pc + high_school_pc + some_college_pc + college_pc + grad_school_pc + white_pc + black_pc + native_american_pc + asian_pc + pacific_islander_pc + other_pc + multi_racial_pc + female_pc + male_pc + unemployment_rate_pc + poverty_rate_pc', data = climate_census).fit().get_robustcov_results()
#      11 #print(lm_housing.params)
#      12 lm_housing_summary = lm_housing.summary()
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in get_robustcov_results(self, cov_type, use_t, **kwds)
#    2143                 self.model, self.params,
#    2144                 normalized_cov_params=self.normalized_cov_params,
# -> 2145                 scale=self.scale)
#    2146
#    2147         res.cov_type = cov_type
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      95         if _cachedval is None:
#      96             # Call the "fget" function
# ---> 97             _cachedval = self.fget(obj)
#      98             # Set the attribute in obj
#      99             # print("Setting %s in cache to %s" % (name, _cachedval))
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in scale(self)
#    1508     def scale(self):
#    1509         wresid = self.wresid
# -> 1510         return np.dot(wresid, wresid) / self.df_resid
#    1511
#    1512     @cache_readonly
#
# ValueError: shapes (2921,152) and (2921,152) not aligned: 152 (dim 1) != 2921 (dim 0)
